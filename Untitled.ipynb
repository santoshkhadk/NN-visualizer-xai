# %%
import numpy as np


X = np.array([[0,0],
              [0,1],
              [1,0],
              [1,1]])

Y = np.array([[0],
              [1],
              [1],
              [0]])

print("XOR Inputs:\n", X)
print("XOR Outputs:\n", Y)
# Out:
# XOR Inputs:
#  [[0 0]
#  [0 1]
#  [1 0]
#  [1 1]]
# XOR Outputs:
#  [[0]
#  [1]
#  [1]
#  [0]]
